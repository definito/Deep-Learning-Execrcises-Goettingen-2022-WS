# %% [markdown]
# # Exercise Sheet 4 - Transfer Learning for Saliency Prediction

# %% [markdown]
# * Deep Learning for Computer Vision – Winter Term 2022/23
# * Organizers: Anwai Archit, Laura Hansel, Michaela Vystrčilová, Constantin Pape
# * Tutors: Anwai Archit, Mai Elshazly, Andreas Schneider, Fabio Seel, Shashwat Sridhar
# * Due date: **Monday, Dec 19, before 14:00**

# %% [markdown]
# In this assignment you will learn how to use transfer learning to predict where people will look in images. We will work with the MIT 1003 dataset which consists of 1003 images together with fixation data from human subjects. Transfer learning allows us to reuse the features from a model that has been pretrained on a larger dataset. Here we will use VGG19 pretrained on ImageNet.
#
# The goals of this assignment are as follows:
#
# *   Extract features from a model pretrained on ImageNet.
# *   Implement a simple readout network and train it on the data.
# *   Define a loss function and a seperate evaluation metric.
# *   Visualize the best and the worst results.
#
# ## Hints
#
# To understand the idea of the exercise sheet, inspired by a paper called DeepGaze we suggest the following.
#
# * Review the lecture
# * It will be very helpful to read the according paper [Kümmerer, Theis, and Bethge (2015)](https://arxiv.org/abs/1411.1045).
#
# Although the general idea of the exercise will be the same as in the paper, we changed some details:
#    * we will use VGG instead of caffe net
#    * we will not do the same thorough analysis and
#    * other details are changed as well to make this exercise simpler.
#
# *Do not hesitate to ask questions and ideally discuss them with your fellow students and tutors on Rocket Chat! We will monitor the channel to provide you help if your discussions get stuck. Also, we are happy to help in our office hours - looking forward seeing you there!*

# %% [markdown]
# ### IMPORTANT SUBMISSION INSTRUCTIONS
#
# - When you've completed the exercise, download the notebook and rename it to `<surname1>_<surname2>_<surname3>.ipynb`
# - Only submit the Jupyter Notebook (ipynb file). No other file is required. Upload it on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission of homework 3`.
# - make only one submission of the exercise per group.
# - The deadline is strict
# - In addition to the submissions, every member of your group should be prepared to present the exercise in the tutorials.
#
# Implementation
# - Only change code to replace placeholders. Leave the other code as is. In addition to the python packages loaded below you are allowed to use any packages you want.

# %% [markdown]
# ### 1. Import required libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from skimage import io, transform
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from scipy.ndimage import gaussian_filter

# %% [markdown]
# ### 2. Get the data
#
# The MIT 1003 dataset is publicly available at https://people.csail.mit.edu/tjudd/WherePeopleLook/index.html
#
# For your convenience there is a shared folder on Google Drive: https://drive.google.com/drive/folders/1GoYw3jp9kWLmHN7qylDS5QTo_ebnaMDD?usp=sharing
# You can click the link and add the folder to your Drive (it does not count into your disk quota).
#
# If you're using Kaggle (recommended) or Colab, you can uncomment the corresponding code in the following cell. With Kaggle you can download the data to your Kaggle environment. With Colab you can to mount your Google drive.

# %%
import utils as utils
from torchinfo import summary
device = utils.get_device()

# %%
# # Steps for Connecting with Google Colab
# """
# # from google.colab import drive
# # drive.mount('/content/drive')
# # import sys
# # sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks/Deep Learning')
# """

# # Steps for Connecting with Kaggle
# """
# Run the scripts as it is by uncommenting the snippets below and it should be fine
# """
# !conda install -y gdown
# # File Location - https://drive.google.com/drive/folders/1NIWYdrGCSFR86mmCBYFDgXs86TMZ9GKo?usp=sharing (we only need the id)
# !gdown --id 1NIWYdrGCSFR86mmCBYFDgXs86TMZ9GKo --folder

# # unzip the mounted 
# ! unzip "/kaggle/working/DL/ALLSTIMULI.zip" -d "MIT_1003"
# ! unzip "/kaggle/working/DL/ALLFIXATIONMAPS.zip" -d "MIT_1003"
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     filelock-3.8.2             |     pyhd8ed1ab_0          14 KB  conda-forge
#     gdown-4.6.0                |     pyhd8ed1ab_0          18 KB  conda-forge
#     openssl-1.1.1s             |       h0b41bf4_1         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.8.2-pyhd8ed1ab_0 None
#   gdown              conda-forge/noarch::gdown-4.6.0-pyhd8ed1ab_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.9.24-ha878542_0 --> 2022.12.7-ha878542_0 None
#   certifi                            2022.9.24-pyhd8ed1ab_0 --> 2022.12.7-pyhd8ed1ab_0 None
#   openssl                                 1.1.1q-h166bdaf_0 --> 1.1.1s-h0b41bf4_1 None
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1s       | 1.9 MB    | ##################################### | 100%
# filelock-3.8.2       | 14 KB     | ##################################### | 100%
# gdown-4.6.0          | 18 KB     | ##################################### | 100%
# ca-certificates-2022 | 143 KB    | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
# /opt/conda/lib/python3.7/site-packages/gdown/cli.py:125: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Retrieving folder list
# Processing file 1NTrioUPinHVrbqW365Psjn_zcL7s9q9Q ALLFIXATIONMAPS.zip
# Processing file 1cuRI22Qs50Exbae3rGch1s1bhlYMKH3M ALLSTIMULI.zip
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1NTrioUPinHVrbqW365Psjn_zcL7s9q9Q
# To: /kaggle/working/DL/ALLFIXATIONMAPS.zip
# 100%|███████████████████████████████████████| 10.5M/10.5M [00:00<00:00, 170MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cuRI22Qs50Exbae3rGch1s1bhlYMKH3M
# To: /kaggle/working/DL/ALLSTIMULI.zip
# 100%|█████████████████████████████████████████| 118M/118M [00:00<00:00, 229MB/s]
# Download completed
# Archive:  /kaggle/working/DL/ALLSTIMULI.zip
#    creating: MIT_1003/ALLSTIMULI/
#   inflating: MIT_1003/__MACOSX/._ALLSTIMULI
#   inflating: MIT_1003/ALLSTIMULI/i1074021825.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1074021825.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1486171792.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1486171792.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2196095208.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2196095208.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1122022227.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1122022227.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1539822082.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1539822082.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1691562175.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1691562175.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2234959271.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2234959271.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2257756967.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2257756967.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1086742403.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1086742403.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1207262076.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1207262076.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1117993383.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1117993383.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i455593157.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i455593157.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2127815415.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2127815415.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1508828.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1508828.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2_2005_dsc04417.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2_2005_dsc04417.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i348747407.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i348747407.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i104935329.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i104935329.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2243369152.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2243369152.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1246371431.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1246371431.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2287732726.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2287732726.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i10feb04_static_cars_highland_img_0843.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i10feb04_static_cars_highland_img_0843.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2278087939.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2278087939.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2257413600.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2257413600.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2295551038.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2295551038.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i126850786.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i126850786.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i107724041.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i107724041.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2289711593.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2289711593.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1172413505.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1172413505.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1075466100.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1075466100.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2229926082.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2229926082.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2132410530.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2132410530.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2277905563.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2277905563.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2282543251.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2282543251.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1248939379.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1248939379.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1936168563.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1936168563.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_urban_city_london_uk_IMG_8638.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_urban_city_london_uk_IMG_8638.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1139715898.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1139715898.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2005_img_0391.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2005_img_0391.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1388704075.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1388704075.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_street_city_cambridge_uk_IMG_8778.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_street_city_cambridge_uk_IMG_8778.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2155595511.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2155595511.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2309997405.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2309997405.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2254450797.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2254450797.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2311048559.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2311048559.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2236128403.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2236128403.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1217965345.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1217965345.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i192592020.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i192592020.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1107916524.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1107916524.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2284956309.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2284956309.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2_2005_dsc04303.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2_2005_dsc04303.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1199505141.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1199505141.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2281397626.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2281397626.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1459316934.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1459316934.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i64011654.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i64011654.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2273502861.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2273502861.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2240569900.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2240569900.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1346278050.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1346278050.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i441014928.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i441014928.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2108405712.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2108405712.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2302491658.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2302491658.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2295106133.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2295106133.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2300935113.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2300935113.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2240165567.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2240165567.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1818663426.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1818663426.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1022085609.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1022085609.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2267710273.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2267710273.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1065169436.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1065169436.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i105126201.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i105126201.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2135366103.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2135366103.jpeg
#   inflating: MIT_1003/ALLSTIMULI/iapril21_static_outdoor_davis_img_0942.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._iapril21_static_outdoor_davis_img_0942.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2297503703.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2297503703.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1485310101.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1485310101.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2264595399.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2264595399.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1843381423.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1843381423.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1847447551.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1847447551.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1131124824.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1131124824.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2096842680.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2096842680.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i128320633.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i128320633.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2211589033.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2211589033.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i204599070.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i204599070.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2174164459.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2174164459.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1025132509.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1025132509.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2168982172.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2168982172.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1490402847.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1490402847.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2168660165.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2168660165.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2194963502.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2194963502.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2274764417.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2274764417.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i106390852.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i106390852.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2145581941.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2145581941.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1252871718.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1252871718.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2062358324.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2062358324.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1395373257.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1395373257.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2269335025.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2269335025.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i10feb04_static_techsquare_img_0873.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i10feb04_static_techsquare_img_0873.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1456209950.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1456209950.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2291139547.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2291139547.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1562869159.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1562869159.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2274770415.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2274770415.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2215088717.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2215088717.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i113347896.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i113347896.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1336805698.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1336805698.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1918259724.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1918259724.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2184058853.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2184058853.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2285970199.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2285970199.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1019928312.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1019928312.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i163744793.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i163744793.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i132418079.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i132418079.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i163125223.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i163125223.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2303119791.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2303119791.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2243931087.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2243931087.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1511249507.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1511249507.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1300905195.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1300905195.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1115183390.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1115183390.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1205929127.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1205929127.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2224739969.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2224739969.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1368359073.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1368359073.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i335910791.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i335910791.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1270375142.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1270375142.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1272116803.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1272116803.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2297752925.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2297752925.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2237001917.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2237001917.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2257749827.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2257749827.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i132306037.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i132306037.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_coast_landscape_outdoor_dsc03095.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_coast_landscape_outdoor_dsc03095.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1176114117.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1176114117.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2200881784.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2200881784.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i05june05_static_street_boston_p1010806.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i05june05_static_street_boston_p1010806.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1977159993.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1977159993.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1132643854.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1132643854.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2304433407.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2304433407.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i160271625.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i160271625.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2310037773.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2310037773.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1177391126.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1177391126.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i30may05_static_street_cambridge_p1010717.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i30may05_static_street_cambridge_p1010717.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2172895099.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2172895099.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1235260142.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1235260142.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2234097332.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2234097332.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1308677325.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1308677325.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1519001350.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1519001350.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1089044309.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1089044309.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1185710392.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1185710392.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1094694998.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1094694998.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_street_outdoor_palma_mallorca_spain_IMG_0459.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_street_outdoor_palma_mallorca_spain_IMG_0459.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1492679408.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1492679408.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2274287237.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2274287237.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_road_mallorca_spain_IMG_0540.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_road_mallorca_spain_IMG_0540.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1335933891.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1335933891.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_hotel_room_indoor_IMG_3274.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_hotel_room_indoor_IMG_3274.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i10941198.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i10941198.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_bay_area_submitted_alyosha_efros_126_2639.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_bay_area_submitted_alyosha_efros_126_2639.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i111373642.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i111373642.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2152854053.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2152854053.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i126277076.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i126277076.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1427114536.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1427114536.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2140171593.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2140171593.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2284954143.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2284954143.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1507520018.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1507520018.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2204386205.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2204386205.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2299085201.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2299085201.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1032393.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1032393.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2_2005_dsc04318.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2_2005_dsc04318.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i113911116.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i113911116.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i130022388.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i130022388.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2290847457.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2290847457.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1222460064.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1222460064.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1351438699.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1351438699.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_palma_outdoor_august_2005_set2_img_1618.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_palma_outdoor_august_2005_set2_img_1618.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1275003744.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1275003744.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1370407372.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1370407372.jpeg
#   inflating: MIT_1003/ALLSTIMULI/syntheticData4.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._syntheticData4.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2204782081.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2204782081.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_urban_city_street_coruna_spain_IMG_8008.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_urban_city_street_coruna_spain_IMG_8008.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i24622350.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i24622350.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2297596765.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2297596765.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2303678791.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2303678791.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1390242687.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1390242687.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i167462665.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i167462665.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2147250639.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2147250639.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2240581851.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2240581851.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2005_img_0308.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2005_img_0308.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i120225437.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i120225437.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i40576393.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i40576393.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1436876661.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1436876661.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i104267087.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i104267087.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2128591182.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2128591182.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i134592788.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i134592788.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1247210024.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1247210024.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_urban_city_street_coruna_spain_IMG_7851.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_urban_city_street_coruna_spain_IMG_7851.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1733711537.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1733711537.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_coast_palafrugel_outdoor_spain_IMG_9165.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_coast_palafrugel_outdoor_spain_IMG_9165.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2278465534.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2278465534.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2174193219.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2174193219.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2240166669.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2240166669.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2257777237.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2257777237.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2278549502.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2278549502.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2197089389.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2197089389.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i116604700.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i116604700.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i05june05_static_street_boston_p1010885.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i05june05_static_street_boston_p1010885.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2202108776.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2202108776.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2202295378.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2202295378.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1117616565.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1117616565.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2292751124.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2292751124.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2197948762.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2197948762.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2229917843.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2229917843.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1797491266.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1797491266.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1986309807.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1986309807.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i106389849.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i106389849.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2079551712.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2079551712.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2085117683.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2085117683.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2158540867.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2158540867.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2305875863.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2305875863.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2239664592.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2239664592.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1272119743.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1272119743.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i117772445.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i117772445.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i129796908.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i129796908.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2222945716.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2222945716.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2301237310.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2301237310.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2277207572.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2277207572.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i200539576.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i200539576.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1232952864.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1232952864.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1970328489.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1970328489.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2_2005_img_0650.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2_2005_img_0650.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1280080218.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1280080218.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1158903665.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1158903665.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1338484745.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1338484745.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i450075958.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i450075958.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2272814913.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2272814913.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1064228254.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1064228254.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1414673039.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1414673039.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2243982741.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2243982741.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1433681776.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1433681776.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2291250914.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2291250914.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1260588917.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1260588917.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2125418545.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2125418545.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i698860717.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i698860717.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_barcelona_street_city_outdoor_2_2005_img_0611.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_barcelona_street_city_outdoor_2_2005_img_0611.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1503092014.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1503092014.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i375779601.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i375779601.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2203431935.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2203431935.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1777084263.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1777084263.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1461500311.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1461500311.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1466094492.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1466094492.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i124682633.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i124682633.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1236338489.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1236338489.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2125430605.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2125430605.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i207747794.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i207747794.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2234137378.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2234137378.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i307151791.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i307151791.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2260404605.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2260404605.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2221573154.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2221573154.jpeg
#   inflating: MIT_1003/ALLSTIMULI/inov6_static_outdoor_img_0522.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._inov6_static_outdoor_img_0522.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_street_city_cambridge_uk_IMG_8702.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_street_city_cambridge_uk_IMG_8702.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i450075962.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i450075962.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i666418509.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i666418509.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1496991666.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1496991666.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2141160962.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2141160962.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2281390926.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2281390926.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1349055388.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1349055388.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_street_city_cambridge_uk_IMG_8893.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_street_city_cambridge_uk_IMG_8893.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1060622926.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1060622926.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1433281460.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1433281460.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i138348611.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i138348611.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_street_outdoor_palma_mallorca_spain_IMG_0706.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_street_outdoor_palma_mallorca_spain_IMG_0706.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1079765858.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1079765858.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2294898365.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2294898365.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2205555719.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2205555719.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i281369959.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i281369959.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i105615320.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i105615320.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2300011983.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2300011983.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2252058417.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2252058417.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2289458290.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2289458290.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_boston_street_april_p1010184.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_boston_street_april_p1010184.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2305344695.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2305344695.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i457818913.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i457818913.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2309143405.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2309143405.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2186422800.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2186422800.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i125218174.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i125218174.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2287434183.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2287434183.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_street_city_barcelona_spain_night_img_1973.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_street_city_barcelona_spain_night_img_1973.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2310105376.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2310105376.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_hotel_room_indoor_IMG_3208.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_hotel_room_indoor_IMG_3208.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1209163197.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1209163197.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1198772915.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1198772915.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2273510179.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2273510179.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i156404992.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i156404992.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2130236527.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2130236527.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_road_mallorca_spain_IMG_0642.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_road_mallorca_spain_IMG_0642.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i207806307.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i207806307.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2211349766.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2211349766.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_newyork_cvpr_celiu_june_2006_IMG_2359.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_newyork_cvpr_celiu_june_2006_IMG_2359.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1427101898.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1427101898.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1190302019.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1190302019.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2301460189.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2301460189.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2232823435.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2232823435.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2208022381.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2208022381.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i126446520.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i126446520.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1043252298.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1043252298.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2254311605.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2254311605.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2208329824.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2208329824.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i11560614.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i11560614.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i134694966.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i134694966.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i110545600.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i110545600.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2308394240.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2308394240.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2286511796.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2286511796.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2230533761.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2230533761.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2238366740.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2238366740.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2286577669.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2286577669.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1025035805.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1025035805.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i156568569.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i156568569.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2265201355.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2265201355.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2264606081.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2264606081.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1872905470.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1872905470.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2249293171.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2249293171.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i41930076.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i41930076.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1139671063.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1139671063.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1815291162.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1815291162.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2214763761.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2214763761.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2129357785.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2129357785.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2257986084.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2257986084.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_hotel_room_indoor_IMG_3265.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_hotel_room_indoor_IMG_3265.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2288544059.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2288544059.jpeg
#   inflating: MIT_1003/ALLSTIMULI/syntheticData3.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._syntheticData3.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2130718051.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2130718051.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i05june05_static_street_boston_p1010816.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i05june05_static_street_boston_p1010816.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i170746079.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i170746079.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1865070582.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1865070582.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i110996888.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i110996888.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2303447136.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2303447136.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1488196573.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1488196573.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i181096125.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i181096125.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2272663539.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2272663539.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1740677522.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1740677522.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i111369435.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i111369435.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2291750140.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2291750140.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2307207961.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2307207961.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_outdoor_nature_tanzania_photos_by_fredo_durand_060811_125130__Z9B0580.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_outdoor_nature_tanzania_photos_by_fredo_durand_060811_125130__Z9B0580.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2296179544.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2296179544.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2275159166.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2275159166.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2127986969.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2127986969.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i05june05_static_street_boston_p1010800.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i05june05_static_street_boston_p1010800.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2051249439.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2051249439.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i133905582.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i133905582.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1390834220.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1390834220.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2280425561.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2280425561.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2155306779.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2155306779.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2310876153.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2310876153.jpeg
#   inflating: MIT_1003/ALLSTIMULI/ioffice_indoor_set2_web_static_despacho.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._ioffice_indoor_set2_web_static_despacho.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1252680396.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1252680396.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1866531260.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1866531260.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1116953942.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1116953942.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2300143227.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2300143227.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1161381449.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1161381449.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2276321014.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2276321014.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1802328941.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1802328941.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2313874233.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2313874233.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i2089736919.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i2089736919.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1843924285.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1843924285.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i13910717.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i13910717.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i113829406.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i113829406.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1325514089.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1325514089.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1465862934.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1465862934.jpeg
#   inflating: MIT_1003/ALLSTIMULI/istatic_houses_boston_2005_IMG_4024.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._istatic_houses_boston_2005_IMG_4024.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1010483663.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1010483663.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i102423191.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i102423191.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1280528250.jpeg
#   inflating: MIT_1003/__MACOSX/ALLSTIMULI/._i1280528250.jpeg
#   inflating: MIT_1003/ALLSTIMULI/i1143924367.jpeg
# ...
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2189914746_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_coast_landscape_outdoor_dsc03095_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_coast_landscape_outdoor_dsc03095_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240165147_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240165147_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2271293627_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2271293627_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1370407372_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1370407372_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i40576393_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i40576393_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2222945716_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2222945716_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010785_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010785_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2172274186_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2172274186_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1572706519_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1572706519_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2275677162_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2275677162_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1338484745_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1338484745_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2289344696_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2289344696_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2148681608_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2148681608_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1260655983_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1260655983_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i160758712_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i160758712_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1519495464_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1519495464_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1795912442_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1795912442_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2290794919_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2290794919_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2281902585_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2281902585_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2291750140_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2291750140_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010855_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010855_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1870142757_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1870142757_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2273330095_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2273330095_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2238477160_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2238477160_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2258108354_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2258108354_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1817839270_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1817839270_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1000978947_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1000978947_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i14020903_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i14020903_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i110545600_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i110545600_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2305314113_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2305314113_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1236338489_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1236338489_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010800_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010800_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1246368617_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1246368617_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2057541_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2057541_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2132126218_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2132126218_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1526935589_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1526935589_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2300935113_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2300935113_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2252058417_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2252058417_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2196095208_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2196095208_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2255893801_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2255893801_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2218506905_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2218506905_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1276571229_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1276571229_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1308677325_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1308677325_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274764417_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274764417_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2211349766_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2211349766_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2229496653_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2229496653_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145105890_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145105890_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1797491266_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1797491266_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286577669_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286577669_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i124682633_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i124682633_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_city_cambridge_uk_IMG_8687_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_city_cambridge_uk_IMG_8687_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1433681776_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1433681776_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2104785691_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2104785691_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2292390104_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2292390104_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1199505141_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1199505141_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1138885959_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1138885959_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2078195666_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2078195666_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274287237_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274287237_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2287747547_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2287747547_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1362671223_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1362671223_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1431286095_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1431286095_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_madrid_outdoor_august_2005_img_0844_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_madrid_outdoor_august_2005_img_0844_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2206265639_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2206265639_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1872398737_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1872398737_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2257413600_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2257413600_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1206857407_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1206857407_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1461500311_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1461500311_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1507520018_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1507520018_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2170431637_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2170431637_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1130496707_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1130496707_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2253396498_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2253396498_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240165567_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240165567_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2127986969_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2127986969_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2174530507_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2174530507_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1032358_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1032358_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_urban_city_street_coruna_spain_IMG_7859_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_urban_city_street_coruna_spain_IMG_7859_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2138748225_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2138748225_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0308_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0308_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145830934_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145830934_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1011319098_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1011319098_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2229917843_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2229917843_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2211589033_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2211589033_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1388450272_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1388450272_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1326772343_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1326772343_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1116123355_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1116123355_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i117772445_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i117772445_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_hotel_room_indoor_IMG_0999_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_hotel_room_indoor_IMG_0999_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2166923001_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2166923001_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1433281460_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1433281460_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286576851_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286576851_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2285970199_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2285970199_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4162_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4162_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1843338577_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1843338577_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1007068829_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1007068829_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2210603425_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2210603425_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2280611353_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2280611353_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2202108776_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2202108776_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i191788956_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i191788956_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240166669_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240166669_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i126605331_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i126605331_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2190823731_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2190823731_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2254311605_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2254311605_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i161218845_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i161218845_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1031604161_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1031604161_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2297596765_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2297596765_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i131993073_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i131993073_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_palma_outdoor_august_2005_set2_img_1618_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_palma_outdoor_august_2005_set2_img_1618_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1071145422_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1071145422_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2305875863_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2305875863_fixPts.jpg

# %%
# main_path = "/kaggle/working/"
# data_path = os.path.join(main_path, "MIT_1003")
main_path = "D:\\STUDY\\MS-MDS\\Deep Learning\\HW\\4"
data_path = os.path.join(main_path, "MIT_1003")

# %% [markdown]
# ### 3. Prepare the data

# %%
images_files_all = sorted([
    os.path.join(data_path, "ALLSTIMULI", f)
    for f in os.scandir(os.path.join(data_path, "ALLSTIMULI"))
    if f.path.endswith(".jpeg")
])
print("Total Number of Images: {} (should be 1003)".format(len(images_files_all)))
# Out:
# Total Number of Images: 1003 (should be 1003)

# %%
# fix the seed for reproducible splitting
np.random.seed(1234)
train_idx = np.random.choice(len(images_files_all), len(images_files_all) // 2, replace=False)
test_idx = np.setdiff1d(np.arange(len(images_files_all)), train_idx)

images_files = {}
images_files["train"] = [images_files_all[i] for i in train_idx]
images_files["test"] = [images_files_all[i] for i in test_idx]
print("Number of Train Images: {}".format(len(images_files["train"])))
print("Number of Test Images: {}".format(len(images_files["test"])))

fixation_maps_binary_files = {}
fixation_maps_binary_files["train"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixPts.jpg")
    for filename in images_files["train"]
]
fixation_maps_binary_files["test"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixPts.jpg")
    for filename in images_files["test"]
]
fixation_maps_blurred_files = {}
fixation_maps_blurred_files["train"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixMap.jpg")
    for filename in images_files["train"]
]
fixation_maps_blurred_files["test"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixMap.jpg")
    for filename in images_files["test"]
]
# Out:
# Number of Train Images: 501
# Number of Test Images: 502

# %% [markdown]
# ### 4. Show an example from the dataset

# %%
image = io.imread(images_files["train"][0])
binary_map = io.imread(fixation_maps_binary_files["train"][0])
blurred_map = io.imread(fixation_maps_blurred_files["train"][0])
fixations = np.where(binary_map)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
ax1.axis("off")
ax1.imshow(image)
ax2.axis("off")
ax2.imshow(blurred_map, cmap="viridis_r")
ax3.axis("off")
ax3.imshow(image, alpha=0.5)
ax3.scatter(fixations[1], fixations[0], s=1, marker=".", c="b")
ax4.axis("off")
ax4.imshow(image)
ax4.imshow(blurred_map, alpha=0.5, cmap="viridis_r")
fig.tight_layout()

# %% [markdown]
# ### 5. Preprocess images and maps
#
# The images have different sizes and orientations. To simplify our task we downscale the images and crop them to a size of 256x256 pixels. At this size, all of the images should fit into memory at once.

# %%
def preprocess_data(images_paths, fixations_binary_paths, fixations_blurred_paths, shape):
    transform = torchvision.transforms.Compose(
        [
            torchvision.transforms.ToPILImage(),
            torchvision.transforms.Resize(shape),
            torchvision.transforms.CenterCrop(shape),
        ]
    )

    n = len(images_paths)
    ims = np.empty((n, shape, shape, 3), dtype=np.int)
    fixs_binary = np.empty((n, shape, shape))
    fixs_blurred = np.empty((n, shape, shape))

    for i, path in enumerate(tqdm(images_paths)):
        image = io.imread(path)
        image = transform(image)
        image = np.array(image, dtype=np.int)
        ims[i] = image

    for i, path in enumerate(tqdm(fixations_binary_paths)):
        fixations_binary = io.imread(path, 0)
        fixations_binary = transform(fixations_binary)
        fixations_binary = np.array(fixations_binary)
        fixs_binary[i] = fixations_binary

    for i, path in enumerate(tqdm(fixations_blurred_paths)):
        fixations_blurred = io.imread(path, 0)
        fixations_blurred = transform(fixations_blurred)
        fixations_blurred = np.array(fixations_blurred)
        fixs_blurred[i] = fixations_blurred

    data = {"images": ims, "fixations_binary": fixs_binary, "fixations_blurred": fixs_blurred}
    return data

# %%
# If data is already preprocessed and saved, load it, otherwise preprocess and save it.
# If you do not whish to save the data comment the according lines.
# If you want to re-run data preprocessing, you may have to delete the saved file.

train_data_file = os.path.join(main_path, "train_data.npy")

if os.path.isfile(train_data_file):
    train_data = np.load(train_data_file, allow_pickle=True)[()]
else:
    train_data = preprocess_data(
        images_files["train"], fixation_maps_binary_files["train"], fixation_maps_blurred_files["train"], 256
    )
    np.save(train_data_file, train_data)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/501 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|██████████| 501/501 [00:13<00:00, 35.81it/s]
# 100%|██████████| 501/501 [00:03<00:00, 160.54it/s]
# 100%|██████████| 501/501 [00:03<00:00, 151.82it/s]

# %% [markdown]
# ### 6. Implement a PyTorch dataset for our data
#
# We need the `torch.utils.data.Dataset`  to access the data conveniently. Later, it is required to have access to the data through this class to build a Pytorch dataloader.

# %%
class ImageDataset(torch.utils.data.Dataset):
    def __init__(self, preprocessed_data, features=None):
        self.features = features
        self.data = preprocessed_data

    def __getitem__(self, key):
        raw_image = self.data["images"][key]

        normalized_image = raw_image.astype(np.float32) / 255.0  # -> [0, 1]
        normalized_image -= np.array([0.485, 0.456, 0.406])  # subtract mean
        normalized_image /= np.array([0.229, 0.224, 0.225])  # divide by SD
        normalized_image = normalized_image.transpose(2, 0, 1)  # HWC -> CHW

        fixations_binary = self.data["fixations_binary"][key]
        fixations_blurred = self.data["fixations_blurred"][key]

        data = {
            "raw_image": raw_image,
            "normalized_image": normalized_image,
            "fixations_binary": fixations_binary,
            "fixations_blurred": fixations_blurred,
        }

        if self.features is not None:
            data["features"] = self.features[key]

        return data

    def __len__(self):
        return len(self.data["images"])

# %% [markdown]
# The collate_fn will be used in the dataloader. It converts the batched data into tensors. We use a sparse tensor for the binary fixations because they contain mostly zeros.

# %%
def to_sparse(x):
    """converts dense tensor x to sparse format"""
    x_typename = torch.typename(x).split(".")[-1]
    sparse_tensortype = getattr(torch.sparse, x_typename)

    indices = torch.nonzero(x)
    if len(indices.shape) == 0:  # if all elements are zeros
        return sparse_tensortype(*x.shape)
    indices = indices.t()
    values = x[tuple(indices[i] for i in range(indices.shape[0]))]
    return sparse_tensortype(indices, values, x.size())


def collate_fn(batch):
    batch_data = {
        "image": torch.tensor([item["normalized_image"] for item in batch]),
        "fixations_binary": to_sparse(torch.tensor([item["fixations_binary"] for item in batch])),
        "fixations_blurred": torch.tensor([item["fixations_blurred"] for item in batch]),
    }
    if "features" in batch[0].keys():
        batch_data["features"] = torch.tensor([item["features"] for item in batch], dtype=torch.float)
    return batch_data

# %% [markdown]
# ### 7. Compute (center) bias
#
# People tend to look towards the center of the image. This is both due to a bias in our expectations as well as the tendency of photographers to place the interesting objects in the center of the photo. Thus, in the fixation data there is a bias towards the center of the image. We can calculate this bias and incorporate it into our model explicitly by using a gaussian filter on the images. The filter will always put more emphasis on what is in the center.
#
# **TO DO:** To compute the bias:
# 1. Sum all the binary fixation maps - *pixels with the highest values will be the ones where people overall looked most at*
# 1. Normalize by dividing through the maximum value - *this way we get values between 0 and 1*
# 1. Apply a Gaussian filter with standard deviation 10 to smooth the result - *smoothing is a way of regularization*
# 1. Compute the natural logarithm
#
# *Hints:*
# - Use the `ImageDataset` class to directly access the data; no pytorch data loader is required here.
# - For Gaussian filtering, you can use `gaussian_filter` from `scipy.ndimage`
#
# **Note:**
# If people had a different bias than towards the center, the steps above would also compute it. But we know the bias is towards the center, that is why it's called center bias.

# %%
from scipy.ndimage import gaussian_filter

# Instantiate the pytorch dataset. (Note that although it contains the same data,
# as `train_data` above, the objects are different. Here, we could use `train_data`)
# instead of `dataset_train`, however, to build a pytorch dataloader later, we
# have to use the `dataset_train` object.

dataset_train = ImageDataset(train_data)
fixations_binary = dataset_train.data["fixations_binary"]

# %%
# TODO
center_bias = ...  # (should be 1 x 256 x 256)
max_value = fixations_binary.sum(0).max()

normal = fixations_binary.sum(0) / max_value
normal = gaussian_filter(normal, sigma=10)
normal = np.log(normal)

center_bias = normal.reshape(1,256,256)
print(center_bias.shape)
# Out:
# (1, 256, 256)

# %% [markdown]
# Plot the result

# %%
plt.figure()
plt.imshow(center_bias[0], cmap="viridis_r")
cb = plt.colorbar().set_label("log density")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Center bias")
# Out:
# Text(0.5, 1.0, 'Center bias')

# %% [markdown]
# Your plot should look like this:
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# Save/Load center bias

# %%
center_bias_file = os.path.join(main_path, "center_bias.npy")

if os.path.isfile(center_bias_file):
    center_bias = np.load(center_bias_file)
else:
    np.save(center_bias_file, center_bias)

# %% [markdown]
# ### 8. Extract feature maps
#
# Load the VGG19 model pretrained on ImageNet. Use it to process the images in the train dataset: For each image, extract its feature map representation from the Conv2d layer `vgg19.features[30]`. For that, you have to constraint the vgg19 model such that all it's layers up to (including) layer 30 process the image. The subsequent layers of the model are not required to extract the feature maps. You should save them in a Numpy array of shape `(num_input_images, num_channels, x, y)`.
#
# **Theory question and hint**:
# - Which shape do you expect for the numpy array? Calculate the values by hand
#     - (501, 512, 16, 16)
# - You can verify that you calculated correctly with the code you will write for this task
#
# *Hints:*
# - Here you will have to define and use a pytorch `DataLoader` object
#     - feed in the train set of type `torch.utils.data.Dataset` created above
#     - use the `collate_fn` defined above
#     - do not shuffle the images (i.e. the data points), so we can save the feature map representations of the images. That way, we can use the feature map representations later and still identify the according image we used to create them.
# - cf. https://pytorch.org/docs/stable/torchvision/models.html. If you are wondering if we normalized images, check code in `ImageDataset`
# - Define a `feature_extractor` object, containing those parts of the pre-trained VGG19 models that you need to extract the feature map representations from the Conv2d layer `vgg19.features[30]`
#     - Don't forget to put your feature extractor in evaluation mode
#     - To avoid problems with memory, you can wrap the feature extraction with `torch.no_grad

# %%
#TODO
vgg = models.vgg19(pretrained = True)

with torch.no_grad():
    feature_extractor = vgg.features[:31]

batch_size = 2

data_loader = torch.utils.data.DataLoader(
    dataset_train,
    shuffle = False,
    batch_size = batch_size,
    collate_fn = collate_fn)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
def compute_train_features(data_loader, feature_extractor):
    # TODO
    array = feature_extractor(next(iter(data_loader))['image']).detach().numpy()
    b = len(array)
    for data in data_loader:
        p = feature_extractor(data['image']).detach().numpy()
        array = np.concatenate((array, p))
    return array[b:]

# %% [markdown]
# ### 9. Save the features to a file
#
# Processing the images can take a few minutes. However, you only have to do it once. Thus it is a good idea to save the features to a file that you can load again later.

# %%
features_file = os.path.join(main_path, "features_train.npy")

if os.path.isfile(features_file):
    features = np.load(features_file)

else:
    features = compute_train_features(data_loader, feature_extractor)

    # sanity check:
    # in the 1st feature map, is the 10 x 10 matrix defined by the first 10
    # height and width entries computed correctly?
    # fmt: off
    expected_values = np.array(
    [[ -5.05856514,  -5.4494257 ,  -4.04797173,  -4.00965357,
         -3.81041431,  -3.70049334,  -3.4691658 ,  -3.33066201,
         -3.46696138,  -3.73726773],
       [ -6.3092165 ,  -6.64189959,  -4.25930309,  -3.98219156,
         -3.24017859,  -3.00728726,  -2.9968071 ,  -3.60749149,
         -4.02913189,  -4.39249563],
       [ -3.42980075,  -3.04784107,  -2.05232024,  -2.40027595,
         -1.40099525,  -0.51563621,   0.20033906,  -0.37016585,
         -0.84697777,  -1.10821617],
       [ -4.69450617,  -4.35960007,  -2.98953676,  -2.70576119,
         -2.62578845,  -2.11511397,  -0.68794125,  -0.58827341,
         -0.71196592,  -0.81783342],
       [ -4.76338863,  -6.2135601 ,  -5.2962575 ,  -5.73660374,
         -5.61037779,  -4.53765774,  -2.5711813 ,  -1.17775714,
          0.11070768,   0.57022107],
       [ -4.61159277,  -7.80154657,  -7.14027071,  -9.02617931,
         -9.96448612,  -9.96775627,  -7.93922615,  -4.81323099,
         -1.49802375,   0.16369806],
       [ -1.97690308,  -5.60399246,  -5.94019413,  -8.35467911,
         -8.34007072, -10.02152252, -10.62400055,  -8.92269707,
         -4.9632473 ,  -2.63384819],
       [ -2.03594875,  -5.8626318 ,  -5.21619272,  -3.86745071,
         -2.13602161,  -4.00327349,  -7.24868536,  -9.66466331,
         -9.5114603 ,  -8.05636787],
       [ -0.08571954,  -2.13494349,  -2.18564558,  -2.49912596,
         -1.9960444 ,  -2.62563705,  -5.04191208,  -7.47077799,
         -8.94375992,  -9.3424015 ],
       [  2.41950774,   1.38582683,   0.01735479,  -5.72050619,
         -5.90604067,  -4.65355062,  -6.06961155,  -7.60495043,
         -8.39218903,  -8.17572594]]
    )
    # fmt: on
    assert np.allclose(features[0, 0, :10, :10], expected_values), "Feature maps look different than expected"

    np.save(features_file, features)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)

# %%
features.shape
# Out:
# (501, 512, 16, 16)

# %% [markdown]
# Add the features to the dataset and define a data loader for training our model. Feel free to change the batch size.

# %%
dataset_train = ImageDataset(train_data, features=features)

data_loader_train = torch.utils.data.DataLoader(
    dataset_train,
    shuffle=True,
    batch_size=64,
    collate_fn=collate_fn,
    pin_memory=False,
)

# %% [markdown]
# ### 10. Define the model
#
# Now we need to define the model we want to train. Two parts are necessary:
#
# 1. Readout Network
#
# The readout network gets the feature maps we extracted from VGG19 as input. The network could be of arbitrary complexity but in our case we want to keep it simple: it contains only one layer that takes a linear combination of the features at each location (using 1x1 convolution).
#
# 2. Finalizer
#
# The finalizer takes the output of the readout network and scales it up to the size of our images (256x256). It then applies a Gaussian filter to blur the result of the upscaling and adds the center bias. Finally, it performs normalization using a (log) softmax to return the logarithm of the fixation probability densities, later refered to as `log_density`.
#
# *Hints:*
# - What are in- and out-shapes of the readout network? What are the parameters you have to pass to the constructor of the 1x1 convolution, then?
#     - The in-shape is (64, 512, 16, 16) & the out-shape is (64, 1, 16, 16).
#     - The parameters are (in_channels, out_channels & kernel_size).
# - Don't forget to give a learnable weight to the center bias, $\alpha$ in [Kümmerer, Theis, and Bethge (2015)](https://arxiv.org/abs/1411.1045).
# - In `Finalizer` below, initialize `self.gaussian_blur = GaussianBlur2d()` and use `self.gaussian_blur` in `forward(...)`.
# - You might want to use `F.interpolate` to scale up the images after the readout network
# - The finalizer output is of shape `(batch, x_pixels, y_pixels)`
# - Use vectorized and torch functions (not for loops)
# - Log softmax: The finalizer should return the logarithm of the fixation probabilities. Here is how to rewrite the math of the paper cited above accordingly:
#
# $$ \ln p(x, y)=\ln \frac{\exp (o(x, y))}{\sum_{x, y} \exp (o(x, y))} = o(x, y)-\ln{\sum_{x, y} \exp (o(x, y))} $$
#
# Where $ p(x,y) $ referst to the probability of a fixation at a certain pixel position $ (x,y) $ and $ o(x,y) $ is the output of the finalizer.
# (Note that in the paper $\log$ refers to the natural logarithm $\ln$. The paper also adds a regularization term which we can ignore in this step). We recommend you to use `logsumexp` to compute the softmax in log-space.

# %%
class GaussianBlur2d(nn.Module):
    """
    This class applies a Gaussian filter to a tensor. You should 
    use it *after* upscaling to image size (256x256). The kernel
    size and the standard deviation are fixed and you don't need
    to change them.
    """
    
    def __init__(self):
        super().__init__()

        self.kernel_size = 121
        self.sigma = 20
        self.pad = 60

        grid = torch.arange(float(self.kernel_size)) - self.pad

        kernel_shape = [self.kernel_size]
        grid = nn.Parameter(grid.view(kernel_shape), requires_grad=False)
        kernel = torch.exp(-0.5 * (grid / self.sigma) ** 2)
        kernel = kernel / kernel.sum()
        self.kernel_x = nn.Parameter(kernel[None, None, :, None], requires_grad=False)
        self.kernel_y = nn.Parameter(kernel[None, None, None, :], requires_grad=False)

        
    def forward(self, tensor):
        """Applies the gaussian filter to the given tensor"""
        out = F.conv2d(tensor, self.kernel_x, padding=self.pad)
        out = F.conv2d(out, self.kernel_y)

        return out

# %%
#TODO
readout_network = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1)

# %%
readout_network(next(iter(data_loader_train))['features']).shape
# Out:
# torch.Size([64, 1, 16, 16])

# %%
class Finalizer(nn.Module):
    """Returns logarithm of the fixation probability densities, shape: (batch, x_size, y_size)"""
    # TODO
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(256,256, bias=False, dtype = float)
        self.gaussian_blur = GaussianBlur2d()
        
    def forward(self, x, centerbias):
        x = F.interpolate(x, size = (256, 256))
        x = self.gaussian_blur(x)
        x = x + self.linear(centerbias)
        x = x.reshape(len(x), 256 * 256)
        x = nn.LogSoftmax(dim=1)(x)
        x = x.reshape(len(x), 256, 256)

        return x

# %%
class Model(nn.Module):
    def __init__(self, readout_network, finalizer):
        super().__init__()
        self.readout_network = readout_network
        self.finalizer = finalizer

    def forward(self, x, centerbias):
        x = self.readout_network(x)
        x = self.finalizer(x, centerbias)
        return x

    def train(self, mode=True):
        self.readout_network.train(mode=mode)
        self.finalizer.train(mode=mode)

# %%
finalizer = Finalizer()
model = Model(readout_network, finalizer)

# %% [markdown]
# ### 11. Define the metrics
#
# We use two different metrics, one for training and one for evaluating the performance of our model. Remember that we did this for the past exercises, too: back then, we used the cross-entropy loss for training and accuracy for validation.
#
# Here, for the training, we use the **negative log-likelihood (NLL)**. Implement a function that calculates the negative log-likelihood of a fixation mask (which are the labels in our data) under the model prediction `log_density` (i.e. the logarithm of the fixation probability density maps).
#
# *Hints:*
# The negative log-likelihood we want to use is a slight modification of the equation (last one on page 3) given in Kümmerer, Theis, and Bethge (2015): we ignore the regularization term. Hence, we obtain
#
# $$c(\alpha, w)=-\frac{1}{N} \sum_{i=1}^{N} \ln \hat{p}\left(x_{i}, y_{i}\right) \ .$$
#
# In the NLL we evaluate the model's predictions. Our model predicts the fixation probability $\hat{p}$ at the positions $(x,y)$. We want to compare it to the number of fixations at these positions in our labeled data. Note that the elements in the binary fixation masks $f(x_j, y_k)$ (our labels) count how many fixations ocurred at position $(x_j, y_k)$.
#
# Let's rewrite the NLL in a way you can directly implement into code: We compute the inner product of the model predictions $\hat{p}(x_j, y_k)$ and ground truth binary fixation masks $f(x_j, y_k)$ (they have the same shape) and divide by the fixation count $N$. Additionally, we compute the mean over images $b$ in our batch. This way, we obtain
#
# $$\tilde{c}(\alpha, w) = \frac{1}{b} \sum_b^B \underbrace{ (-1) \frac{1}{N} \sum_{j,k} \ln (\hat{p}(x_{j}, y_{k} |\, \mathrm{image} \ b)) \cdot f(x_{j},y_{k} |\, \mathrm{image} \ b) }_{c(\alpha, w)} \ .$$
#
# **Note:**
# - The conditioning on the image is there to express that the probability of fixations we predict is conditioned, i.e. depends on the image for which we are predicting the fixations.
#
# **Questions:**
# - Why can we re-write the expression $c(\alpha, w)$ like this?
#     - Because large value for f(x, y) means the corresponding predicted probability should be high and small value means low probability, the we can multiply them since they represent the same trend.
# - What values can the elements of $f(x_{j},y_{k} |\, \mathrm{image} \ b)$ obtain?
#     - Any integers bigger than 0.
# - On the lecture slides the loss contained a *sum* over images. Here, for practical reasons we compute the *mean* over images instead. Why is that advantageous?
#     - Taking the mean can make the comparsion of the result easier when the training datasets have different size, also helps the model to handle outliers and makes the model more stable and computationally efficient when dealing with large data.
#
#
# Implement $\tilde{c}(\alpha, w)$. You may want to
# - Convert the sparse binary `fixation_mask` to a dense one using `t.to_dense()` to be able to compute the inner product of $f$ with the predictions $\hat{p}$.
# - Compute the mean across batches

# %%
def neg_log_likelihood(log_predictions, fixation_mask):
    #TODO
    fixation = fixation_mask.to_dense()
    inner = log_predictions * fixation
    N = fixation.sum(1).sum(1)
    C = -1 * inner.sum(1).sum(1) / N
    NLL = C.sum() / 64
    return NLL

# %% [markdown]
# For evaluation, we want to use the *normalized scanpath saliency* (NSS; [Peters, Iyer, Itti, and Koch (2005), Section 2.10](https://doi.org/10.1016/j.visres.2005.03.019)). To compute NSS, normalize the model's saliency map which is the model's prediction $\mathrm{SM}(x,y)$ to have zero mean and unit standard deviation,
#
# $$Z_{\mathrm{SM}}(x,y) = \frac{\mathrm{SM}(x,y) - \mu}{\sigma}\ ,$$
#
# where $\mu$ and $\sigma$ are the mean and the standard deviation of the saliency map, respectively. Then, average the according responses at all fixations $(x_i,y_i)$,
#
# $$\mathrm{NSS} = \frac{1}{b} \sum_b^B {(\frac{1}{N} \sum_{j,k} {Z_{SM}}(x_{j}, y_{k} |\, \mathrm{image} \ b) \cdot f(x_{j},y_{k} |\, \mathrm{image} \ b))}\ $$
#
# Implement this as a function.
#
# *Hints:*
# - For the evaluation of this metric, the saliency map $\mathrm{SM}(x,y)$ is *not* supposed to be in log-space. Therefore the saliency map should be given an exponential of the `log_predictions`: $\mathrm{e}^{\hat{p}(x, y)}$.
# - Remember the hints from above:
#     - Compute the mean across batches

# %%
def nss(log_predictions, fixation_mask):
    #TODO
    fixation = fixation_mask.to_dense()
    SM = torch.exp(log_predictions)
    for i in range(SM.shape[0]):
        SM[i] = (SM[i] - torch.mean(SM[i])) / torch.std(SM[i])
        SM[SM < 0] = 0
    inner = SM * fixation
    N = fixation.sum(1).sum(1)
    NS = inner.sum(1).sum(1) / N
    NSS = NS.sum() / 64
    return NSS

# %% [markdown]
# ### 12. Train the model
#
# Now iterate through the dataloader to train the model on the train dataset. You can use the Adam optimizer with default parameters. You should print the NLL and the NSS of the train dataset after each training epoch to monitor the progress. Train for at least 5 epochs. You are welcome to reuse and adapt the code you used on the previous exercise sheets for model training, but you don't have to.
#
# *Hints:*
# - Do we want to maximize or minimize the negative log-likelihood?
#     - Minimize the NLL.
# - In our reference implementation, after the fifth epoch we got `NLL: 10.0   NSS: 3.9`

# %%
import fastprogress
import time

# %%
def train(dataloader, centerbias, optimizer, model, nll, nss, master_bar):
    """Run one training epoch.

    Args:
        dataloader (DataLoader): Torch DataLoader object to load data
        optimizer: Torch optimizer object
        model (nn.Module): Torch model to train
        loss_fn: Torch loss function
        device (torch.device): Torch device to use for training
        master_bar (fastprogress.master_bar): Will be iterated over for each
            epoch to draw batches and display training progress

    Returns:
        float, float: Mean loss of this epoch, fraction of correct predictions
            on training set (accuracy)
    """
    epoch_loss_nll = []
    epoch_loss_nss = []
    

    for x in fastprogress.progress_bar(dataloader, parent=master_bar):
        
        feature = x['features']
        fixation = x['fixations_binary']
        
        optimizer.zero_grad()
        model.train()

        # Forward pass
        pred = model(feature, torch.tensor(centerbias))

        # Compute loss
        loss_nll = nll(pred, fixation)
        loss_nss = nss(pred, fixation)

        # Backward pass
        loss_nll.backward()
        optimizer.step()

        # For plotting the train loss, save it for each sample
        epoch_loss_nll.append(loss_nll.item())
        epoch_loss_nss.append(loss_nss.item())

    # Return the mean loss and the accuracy of this epoch
    
    return np.mean(epoch_loss_nll), np.mean(epoch_loss_nss)

# %%
def run_training(model, centerbias, optimizer, nll, nss, num_epochs, train_dataloader):
    
    start_time = time.time()
    master_bar = fastprogress.master_bar(range(num_epochs))
    for epoch in master_bar:
        a, b = train(train_dataloader, centerbias, optimizer, model, nll, nss, master_bar)
        print('epoch =', epoch + 1)
        print('Loss_nll =', a)
        print('Loss_nss =', b)
        print('')

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
model = model
nll = neg_log_likelihood
nss = nss
run_training(model, center_bias, optimizer, nll, nss, 5, data_loader_train)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# epoch = 1
# Loss_nll = 22.149741629116843
# Loss_nss = 0.2610783361213748
#
# epoch = 2
# Loss_nll = 28.900761829986756
# Loss_nss = 0.15139546802519194
#
# epoch = 3
# Loss_nll = 25.34438821551651
# Loss_nss = 0.16138947315254326
#
# epoch = 4
# Loss_nll = 20.26347107582309
# Loss_nss = 0.3307311849597619
#
# epoch = 5
# Loss_nll = 15.380023444333313
# Loss_nss = 0.44693346389787814

# %% [markdown]
# You can save the model to disk if you want to.

# %%
# model_file = os.path.join(main_path, 'model_name.torch')

# if os.path.isfile(model_file):
#     model.load_state_dict(torch.load(model_file))
#     model.eval()
# else:
#     %time run_training(model, data_loader_train, torch.tensor(center_bias, dtype=torch.float))
#     torch.save(model.state_dict(), model_file)

# %% [markdown]
# ### 13. Get the scores for the test data

# %%
test_data = preprocess_data(
    images_files["test"], fixation_maps_binary_files["test"], fixation_maps_blurred_files["test"], 256
)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/502 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|██████████| 502/502 [00:12<00:00, 41.23it/s]
# 100%|██████████| 502/502 [00:03<00:00, 155.83it/s]
# 100%|██████████| 502/502 [00:03<00:00, 147.43it/s]

# %% [markdown]
# Here you need to extract the same feature maps as you extracted before, but now for the test images instead of the training images. It works the same way as before for the train dataset.

# %%
def compute_test_features(data_loader, feature_extractor):
    # TODO
    array = feature_extractor(next(iter(data_loader))['image']).detach().numpy()
    b = len(array)
    for data in data_loader:
        p = feature_extractor(data['image']).detach().numpy()
        array = np.concatenate((array, p))
    return array[b:]

# %% [markdown]
# save / load

# %%
dataset_test = ImageDataset(test_data)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    shuffle=False,
    batch_size=8,
    collate_fn=collate_fn,
    pin_memory=False,
)

# %%
features_test_file = os.path.join(main_path, "features_test.npy")

if os.path.isfile(features_test_file):
    features_test = np.load(features_test_file)
else:
    features_test = compute_test_features(data_loader_test, feature_extractor)
    np.save(features_test_file, features_test)

# %% [markdown]
# Get the NSS scores for each test image. Print the three highest NSS scores. In our reference implementation, we got `[6.0, 7.1, 7.3]`.

# %%
dataset_test = ImageDataset(test_data, features=features_test)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    shuffle=False,
    batch_size=1,
    collate_fn=collate_fn,
    pin_memory=False,
)

# %%
scores = []
fixation = []
pred = []
model.eval()
for data in data_loader_test:
    x = data['features']
    y = data['fixations_binary']
    p = model(x, torch.tensor(center_bias))
    pred.append(p)
    scores.append(nss(p, y).item())
    fixation.append(y)

# %%
s = scores
s = np.sort(s)
print(s[-1])
print(s[-2])
print(s[-3])
# Out:
# 0.06655205726661358
# 0.05572882667007147
# 0.04988436036830639

# %% [markdown]
# ### 14. Inspect the results
#
# Let's find out how well your model performs. Use the given plot function to visualize the saliency maps for
# 1. the three elements of the test dataset with the *highest NSS* and
# 2. the three elements of the test dataset with the *lowest NSS*.
#
# Print the respective NSS values.

# %% [markdown]
# **Display test images with highest scores**
#
# For the images with the highest scores the predicted saliency map should look very similar to the observed fixation map.
#
# Here is an example:
#
# ![alt text](https://i.imgur.com/qgUQG2W.png)

# %%
def plot(image, fixations, blurred_map, prediction):
    fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize = (10,5))

    ax1.axis("off")
    ax1.imshow(image)
    ax1.set_title("original image")

    ax2.axis("off")
    ax2.imshow(blurred_map, cmap="viridis_r")
    ax2.set_title("blurred fixation map")

    ax3.axis("off")
    ax3.imshow(prediction, cmap="viridis_r")
    ax3.set_title("model prediction")

    ax4.axis("off")
    ax4.imshow(image, alpha=0.5)
    ax4.scatter(fixations[1], fixations[0], s=10, marker=".", c="b")
    ax4.set_title("overlayed with discrete fixations")

    ax5.axis("off")
    ax5.imshow(image)
    ax5.imshow(blurred_map, alpha=0.5, cmap="viridis_r")
    ax5.set_title("overlayed with original image")

    ax6.axis("off")
    ax6.imshow(image)
    ax6.imshow(prediction, alpha=0.5, cmap="viridis_r")
    ax6.set_title("overlayed with original image")

# %%
# TODO
image = test_data['images'][np.argmax(scores)]
fixations = fixation[np.argmax(scores)]._indices()[1:]
blurred_map = test_data['fixations_blurred'][np.argmax(scores)]
prediction = torch.exp(pred[np.argmax(scores)].detach().reshape(256, 256))
plot(image, fixations, blurred_map, prediction)

# %% [markdown]
# **Display test images with lowest scores**
#
# Here is an example for which the prediction is poor:
#
# ![alt text](https://i.imgur.com/g4rD2O1.png)

# %%
# TODO
image = test_data['images'][np.argmin(scores)]
fixations = fixation[np.argmin(scores)]._indices()[1:]
blurred_map = test_data['fixations_blurred'][np.argmin(scores)]
prediction = torch.exp(pred[np.argmin(scores)].detach().reshape(256, 256))
plot(image, fixations, blurred_map, prediction)
